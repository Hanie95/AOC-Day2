# %%
import numpy as np
np.random.rand()
# Out:
# 0.23019669415375998

# %%
import numpy as np
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946

# %%
np.random.rand()
# Out:
# 0.2268514535642031

# %%
print(np.random.rand())
# Out:
# 0.5513147690828912

# %%
coin = np.random.randint(0,2)
print(coin)
if coin == 0:
    print('heads')

else:
    print('tails')
# Out:
# 1
# tails

# %%
import numpy as np
import pandas as pd 
import math 
import os 

df = pd.read_excel('Book21.xlsx', sheet_name ='Book21')
x= df.to_numpy()
lists ={"1": ["d","b","j","v"],"2":["p","v","b","w","r","d","f"], "3":["r","g", "f","l","d","c","w","q"],"4":["w","j","p","M","L","N","d","b"],"5":["h","n","b","p","c","s","q"],"6":["r","d","b","s","n","g"],"7":["z","b","p","m","q","f","s","h"],"8":["w","L","F"],"9":["s","v","f","m","r"]}

commands = x[0]


for c in commands:
  count = int(c.rsplit("move ")[1].rsplit(" from")[0])
  source = str(c.rsplit("from ")[1].rsplit(" to")[0])
  target = str(c.rsplit("to ")[1])
  print(count)
  print(source)
  print(target)

  for i in range (0, count):

    y = lists[source]
    z = lists[target]
    z.append(y[-1])
    del y[-1]
  print(lists)
# Out:
# 1
# 4
# 1
# {'1': ['d', 'b', 'j', 'v', 'b'], '2': ['p', 'v', 'b', 'w', 'r', 'd', 'f'], '3': ['r', 'g', 'f', 'l', 'd', 'c', 'w', 'q'], '4': ['w', 'j', 'p', 'M', 'L', 'N', 'd'], '5': ['h', 'n', 'b', 'p', 'c', 's', 'q'], '6': ['r', 'd', 'b', 's', 'n', 'g'], '7': ['z', 'b', 'p', 'm', 'q', 'f', 's', 'h'], '8': ['w', 'L', 'F'], '9': ['s', 'v', 'f', 'm', 'r']}
# 2
# 4
# 8
# {'1': ['d', 'b', 'j', 'v', 'b'], '2': ['p', 'v', 'b', 'w', 'r', 'd', 'f'], '3': ['r', 'g', 'f', 'l', 'd', 'c', 'w', 'q'], '4': ['w', 'j', 'p', 'M', 'L'], '5': ['h', 'n', 'b', 'p', 'c', 's', 'q'], '6': ['r', 'd', 'b', 's', 'n', 'g'], '7': ['z', 'b', 'p', 'm', 'q', 'f', 's', 'h'], '8': ['w', 'L', 'F', 'd', 'N'], '9': ['s', 'v', 'f', 'm', 'r']}
# 5
# 9
# 6
# ...
